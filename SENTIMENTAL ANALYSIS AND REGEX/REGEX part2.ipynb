# %% [markdown]
# # REGEX

# %% [markdown]
# ## What is Regex (Regular Expressions)?
#        Regex (short for Regular Expressions) is like a search pattern used to match text.
#
#      1.It’s basically a sequence of characters that defines a rule for finding strings inside text.
#
#      2.Think of it like a CTRL+F on steroids → much more powerful than normal search.

# %% [markdown]
# ## Why Do We Need Regex?
# -- In Machine Learning, Regex is not a model, but a preprocessing / feature engineering tool.We use it mostly in text-based ML tasks (NLP).
#
# We need regex when we want to:
#
#   1. Search → Find a pattern in text
#
#   2. Validate → Check if input follows rules
#
#   3. Extract → Pull out useful pieces of text
#
#   4. Replace/Clean → Modify text based on patterns

# %%
import pandas as pd

# Load CSV
df = pd.read_csv("reviews.csv")
df.head()
# Out:
#    ID         Name                   Email       Phone  \
# 0   1     John Doe    john.doe@example.com  9876543210
# 1   2   Jane Smith  jane.smith@example.com  9123456789
# 2   3  Bob Johnson       bob.j@example.com  9988776655
# 3   4  Alice Brown     alice.b@example.com  9871122334
# 4   5  Charlie Lee   charlie.l@example.com  9765432109
#
#                                    Review
# 0                I love Python!!! #AI #ML
# 1  Worst experience 😡, never coming back!
# 2  Check out my blog: https://example.com
# 3        Amazing service!!! 5 stars ⭐⭐⭐⭐⭐
# 4       Not satisfied, needs improvement.

# %%
import re

# %%
df[df['Review'].str.contains(r"^love", flags=re.IGNORECASE, regex=True)]
# Out:
#     ID         Name                Email       Phone  \
# 8    9   Grace Hall  grace.h@example.com  9321098765
# 24  25  Wendy Lewis  wendy.l@example.com  9543210984
#
#                                      Review
# 8   Loved the experience, highly recommend.
# 24             Loved the colors and design.

# %%
# Emails starting with “bob”
df[df['Email'].str.contains(r'^bob', regex=True, na=False)]
# Out:
#    ID         Name              Email       Phone  \
# 2   3  Bob Johnson  bob.j@example.com  9988776655
#
#                                    Review
# 2  Check out my blog: https://example.com

# %%
df[df['Phone'].astype(str).str.contains(r'^9', regex=True, na=False)]
# Out:
#     ID           Name                   Email       Phone  \
# 0    1       John Doe    john.doe@example.com  9876543210
# 1    2     Jane Smith  jane.smith@example.com  9123456789
# 2    3    Bob Johnson       bob.j@example.com  9988776655
# 3    4    Alice Brown     alice.b@example.com  9871122334
# 4    5    Charlie Lee   charlie.l@example.com  9765432109
# 5    6      David Kim     david.k@example.com  9654321098
# 6    7      Eve Davis       eve.d@example.com  9543210987
# 7    8    Frank Moore     frank.m@example.com  9432109876
# 8    9     Grace Hall     grace.h@example.com  9321098765
# 9   10     Hank Allen      hank.a@example.com  9210987654
# 10  11      Ivy Scott       ivy.s@example.com  9109876543
# 11  12     Jack White      jack.w@example.com  9898765432
# 12  13    Karen Young     karen.y@example.com  9787654321
# 13  14      Liam King      liam.k@example.com  9676543210
# 14  15     Mia Wright       mia.w@example.com  9565432109
# 15  16      Noah Hill      noah.h@example.com  9454321098
# 16  17   Olivia Green    olivia.g@example.com  9343210987
# 17  18     Paul Adams      paul.a@example.com  9232109876
# 18  19    Quinn Baker     quinn.b@example.com  9121098765
# 19  20   Rachel Clark    rachel.c@example.com  9010987654
# 20  21      Sam Evans       sam.e@example.com  9987654321
# 21  22    Tina Foster      tina.f@example.com  9876543211
# 22  23     Uma Harris       uma.h@example.com  9765432102
# 23  24   Victor Jones    victor.j@example.com  9654321093
# 24  25    Wendy Lewis     wendy.l@example.com  9543210984
# 25  26  Xander Miller    xander.m@example.com  9432109875
# 26  27    Yara Nelson      yara.n@example.com  9321098766
# 27  28     Zack Owens      zack.o@example.com  9210987657
# 28  29    Alice Perry     alice.p@example.com  9109876548
# 29  30    Brian Quinn     brian.q@example.com  9898765439
#
#                                      Review
# 0                  I love Python!!! #AI #ML
# 1    Worst experience 😡, never coming back!
# 2    Check out my blog: https://example.com
# 3          Amazing service!!! 5 stars ⭐⭐⭐⭐⭐
# 4         Not satisfied, needs improvement.
# 5            Great product, will buy again!
# 6             Terrible delivery, very late!
# 7           Excellent support and guidance.
# 8   Loved the experience, highly recommend.
# 9             Poor packaging, item damaged.
# 10           Amazing quality for the price.
# 11         Delivery was fast and efficient.
# 12        Customer service could be better.
# 13         Fantastic features, very useful.
# 14     Disappointed with the color options.
# 15                Easy to use and reliable.
# 16                     Not worth the money.
# 17      Highly satisfied, will order again.
# 18            Product arrived as described.
# 19          Customer support was unhelpful.
# 20            Very user-friendly interface.
# 21                  Shipping took too long.
# 22           Excellent quality and service.
# 23     Poor instructions, hard to assemble.
# 24             Loved the colors and design.
# 25                   Battery life is short.
# 26                   Great value for money.
# 27          Not as described, disappointed.
# 28        Fast delivery and good packaging.
# 29       Amazing! Exceeded my expectations.

# %%
df[df['Name'].str.contains(r'^[AEIOUaeiou]', regex=True, na=False)]
# Out:
#     ID          Name                 Email       Phone  \
# 3    4   Alice Brown   alice.b@example.com  9871122334
# 6    7     Eve Davis     eve.d@example.com  9543210987
# 10  11     Ivy Scott     ivy.s@example.com  9109876543
# 16  17  Olivia Green  olivia.g@example.com  9343210987
# 22  23    Uma Harris     uma.h@example.com  9765432102
# 28  29   Alice Perry   alice.p@example.com  9109876548
#
#                                Review
# 3    Amazing service!!! 5 stars ⭐⭐⭐⭐⭐
# 6       Terrible delivery, very late!
# 10     Amazing quality for the price.
# 16               Not worth the money.
# 22     Excellent quality and service.
# 28  Fast delivery and good packaging.

# %%
# $-Ends with
df[df['Email'].str.contains(r'example.com$', regex=True, na=False)]
# Out:
#     ID           Name                   Email       Phone  \
# 0    1       John Doe    john.doe@example.com  9876543210
# 1    2     Jane Smith  jane.smith@example.com  9123456789
# 2    3    Bob Johnson       bob.j@example.com  9988776655
# 3    4    Alice Brown     alice.b@example.com  9871122334
# 4    5    Charlie Lee   charlie.l@example.com  9765432109
# 5    6      David Kim     david.k@example.com  9654321098
# 6    7      Eve Davis       eve.d@example.com  9543210987
# 7    8    Frank Moore     frank.m@example.com  9432109876
# 8    9     Grace Hall     grace.h@example.com  9321098765
# 9   10     Hank Allen      hank.a@example.com  9210987654
# 10  11      Ivy Scott       ivy.s@example.com  9109876543
# 11  12     Jack White      jack.w@example.com  9898765432
# 12  13    Karen Young     karen.y@example.com  9787654321
# 13  14      Liam King      liam.k@example.com  9676543210
# 14  15     Mia Wright       mia.w@example.com  9565432109
# 15  16      Noah Hill      noah.h@example.com  9454321098
# 16  17   Olivia Green    olivia.g@example.com  9343210987
# 17  18     Paul Adams      paul.a@example.com  9232109876
# 18  19    Quinn Baker     quinn.b@example.com  9121098765
# 19  20   Rachel Clark    rachel.c@example.com  9010987654
# 20  21      Sam Evans       sam.e@example.com  9987654321
# 21  22    Tina Foster      tina.f@example.com  9876543211
# 22  23     Uma Harris       uma.h@example.com  9765432102
# 23  24   Victor Jones    victor.j@example.com  9654321093
# 24  25    Wendy Lewis     wendy.l@example.com  9543210984
# 25  26  Xander Miller    xander.m@example.com  9432109875
# 26  27    Yara Nelson      yara.n@example.com  9321098766
# 27  28     Zack Owens      zack.o@example.com  9210987657
# 28  29    Alice Perry     alice.p@example.com  9109876548
# 29  30    Brian Quinn     brian.q@example.com  9898765439
#
#                                      Review
# 0                  I love Python!!! #AI #ML
# 1    Worst experience 😡, never coming back!
# 2    Check out my blog: https://example.com
# 3          Amazing service!!! 5 stars ⭐⭐⭐⭐⭐
# 4         Not satisfied, needs improvement.
# 5            Great product, will buy again!
# 6             Terrible delivery, very late!
# 7           Excellent support and guidance.
# 8   Loved the experience, highly recommend.
# 9             Poor packaging, item damaged.
# 10           Amazing quality for the price.
# 11         Delivery was fast and efficient.
# 12        Customer service could be better.
# 13         Fantastic features, very useful.
# 14     Disappointed with the color options.
# 15                Easy to use and reliable.
# 16                     Not worth the money.
# 17      Highly satisfied, will order again.
# 18            Product arrived as described.
# 19          Customer support was unhelpful.
# 20            Very user-friendly interface.
# 21                  Shipping took too long.
# 22           Excellent quality and service.
# 23     Poor instructions, hard to assemble.
# 24             Loved the colors and design.
# 25                   Battery life is short.
# 26                   Great value for money.
# 27          Not as described, disappointed.
# 28        Fast delivery and good packaging.
# 29       Amazing! Exceeded my expectations.

# %%
df[df['Phone'].astype(str).str.contains(r'5$', regex=True, na=False)]
# Out:
#     ID           Name                 Email       Phone  \
# 2    3    Bob Johnson     bob.j@example.com  9988776655
# 8    9     Grace Hall   grace.h@example.com  9321098765
# 18  19    Quinn Baker   quinn.b@example.com  9121098765
# 25  26  Xander Miller  xander.m@example.com  9432109875
#
#                                      Review
# 2    Check out my blog: https://example.com
# 8   Loved the experience, highly recommend.
# 18            Product arrived as described.
# 25                   Battery life is short.

# %%
# Replace the values
df['Email'] = df['Email'].str.replace(r'[@.]', '_', regex=True)

# %%
df
# Out:
#     ID           Name                   Email       Phone  \
# 0    1       John Doe    john_doe_example_com  9876543210
# 1    2     Jane Smith  jane_smith_example_com  9123456789
# 2    3    Bob Johnson       bob_j_example_com  9988776655
# 3    4    Alice Brown     alice_b_example_com  9871122334
# 4    5    Charlie Lee   charlie_l_example_com  9765432109
# 5    6      David Kim     david_k_example_com  9654321098
# 6    7      Eve Davis       eve_d_example_com  9543210987
# 7    8    Frank Moore     frank_m_example_com  9432109876
# 8    9     Grace Hall     grace_h_example_com  9321098765
# 9   10     Hank Allen      hank_a_example_com  9210987654
# 10  11      Ivy Scott       ivy_s_example_com  9109876543
# 11  12     Jack White      jack_w_example_com  9898765432
# 12  13    Karen Young     karen_y_example_com  9787654321
# 13  14      Liam King      liam_k_example_com  9676543210
# 14  15     Mia Wright       mia_w_example_com  9565432109
# 15  16      Noah Hill      noah_h_example_com  9454321098
# 16  17   Olivia Green    olivia_g_example_com  9343210987
# 17  18     Paul Adams      paul_a_example_com  9232109876
# 18  19    Quinn Baker     quinn_b_example_com  9121098765
# 19  20   Rachel Clark    rachel_c_example_com  9010987654
# 20  21      Sam Evans       sam_e_example_com  9987654321
# 21  22    Tina Foster      tina_f_example_com  9876543211
# 22  23     Uma Harris       uma_h_example_com  9765432102
# 23  24   Victor Jones    victor_j_example_com  9654321093
# 24  25    Wendy Lewis     wendy_l_example_com  9543210984
# 25  26  Xander Miller    xander_m_example_com  9432109875
# 26  27    Yara Nelson      yara_n_example_com  9321098766
# 27  28     Zack Owens      zack_o_example_com  9210987657
# 28  29    Alice Perry     alice_p_example_com  9109876548
# 29  30    Brian Quinn     brian_q_example_com  9898765439
#
#                                      Review
# 0                  I love Python!!! #AI #ML
# 1    Worst experience 😡, never coming back!
# 2    Check out my blog: https://example.com
# 3          Amazing service!!! 5 stars ⭐⭐⭐⭐⭐
# 4         Not satisfied, needs improvement.
# 5            Great product, will buy again!
# 6             Terrible delivery, very late!
# 7           Excellent support and guidance.
# 8   Loved the experience, highly recommend.
# 9             Poor packaging, item damaged.
# 10           Amazing quality for the price.
# 11         Delivery was fast and efficient.
# 12        Customer service could be better.
# 13         Fantastic features, very useful.
# 14     Disappointed with the color options.
# 15                Easy to use and reliable.
# 16                     Not worth the money.
# 17      Highly satisfied, will order again.
# 18            Product arrived as described.
# 19          Customer support was unhelpful.
# 20            Very user-friendly interface.
# 21                  Shipping took too long.
# 22           Excellent quality and service.
# 23     Poor instructions, hard to assemble.
# 24             Loved the colors and design.
# 25                   Battery life is short.
# 26                   Great value for money.
# 27          Not as described, disappointed.
# 28        Fast delivery and good packaging.
# 29       Amazing! Exceeded my expectations.
